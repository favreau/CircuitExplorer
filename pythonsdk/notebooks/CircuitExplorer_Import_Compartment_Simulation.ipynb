# %%
from brayns import Client
from circuitexplorer import CircuitExplorer
brayns = Client('localhost:5000')
ce = CircuitExplorer(brayns)

# %%
config = '/home/favreau/bluebrain/install/release/share/BBPTestData/circuitBuilding_1000neurons/BlueConfig'

# %%
import os
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from tqdm.notebook import tqdm

db_host = os.getenv('DB_HOST')
db_name = os.getenv('DB_NAME')
db_user = os.getenv('DB_USER')
db_password = os.getenv('DB_PASSWORD')
db_schema = 'test_data'

# db_connection_string = 'postgresql+psycopg2://%s:%s@%s:5432/%s' % (db_user, db_password, db_host, db_name)

db_connection_string = 'host=' + db_host + ' port=5432 dbname=' + db_name + ' user=' + db_user + ' password=' + db_password
print('Connection string: ' + db_connection_string + ', schema: ' + db_schema)
# Out:
# Connection string: host=postgresql14-users.bbp.epfl.ch port=5432 dbname=bioexplorer user=bioexplorer password=verole2020, schema: test_data

# %%
ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
# Out:
# Future exception was never retrieved
# future: <Future finished exception=ConnectionClosed('WebSocket connection is closed: code = 1006 (connection closed abnormally [internal]), no reason')>
# websockets.exceptions.ConnectionClosed: WebSocket connection is closed: code = 1006 (connection closed abnormally [internal]), no reason
# ---------------------------------------------------------------------------
# RequestError                              Traceback (most recent call last)
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_10407/625078116.py in <module>
# ----> 1 ce.import_compartment_simulation(db_connection_string, db_schema, config, 'voltages', 2)
#
# ~/Notebooks/env/lib/python3.8/site-packages/circuitexplorer/circuit_explorer.py in import_compartment_simulation(self, db_connection_string, db_schema, blue_config, report_name, report_id)
#     947         params['reportName'] = report_name
#     948         params['reportId'] = report_id
# --> 949         return self._client.request(self.PLUGIN_API_PREFIX + 'import-compartment-simulation', params,
#     950                                     response_timeout=self.DEFAULT_RESPONSE_TIMEOUT)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in request(self, method, params, response_timeout)
#      98         :raises TimeoutError: if request was not answered within given response_timeout
#      99         """
# --> 100         return self._call_sync(self._client.request(method, params), response_timeout)
#     101
#     102     @copydoc(AsyncClient.batch)
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/client.py in _call_sync(self, original_function, response_timeout)
#     117                 original_function, self._client.loop
#     118             )
# --> 119             return future.result(response_timeout)
#     120         return self._client.loop.run_until_complete(original_function)
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# ~/Notebooks/env/lib/python3.8/site-packages/rockets/async_client.py in request(self, method, params)
#     169
#     170             await self.send(request.json)
# --> 171             await response_future
#     172             return response_future.result()
#     173         except asyncio.CancelledError:
#
# RequestError: Socket connection closed
